# %% [markdown]
# # Detroit Open Demolitions
# ### Public X Design Workshop, Detroit, Sep, 2018
# #### We are Avigail Vantu (avigailvantu@gmail.com) & Eitan Akman (eitanakman@gmail.com), we are both cities, tech and data enthusiastic based in Brookyln, NY and are very excited to be visting Detroit.

# %% [markdown]
# # ****EA link to notebooks + explaining bugs and scenarios along the lab****

# %% [markdown]
# Hey there! Welcome to our workshop!
#
# All are welcome, and there are no prerequisiten needed to participate. Today we want to use data to better understand Detroit's demolitions policies. All of the data we will be working on in these session is released as open data - meaning it is accessible online for everyone to use. In particular, Detroit's Open Data Portal was used in this notebook descriptives and analysis: https://data.detroitmi.gov/

# %% [markdown]
# ### Agenda:
#     1. Introduction: Workshop Objectives & Intro to Open data  / databases , Jupyter, and Python
#     2. Demolitions Data
#     3. Short term impact
#         a. 311 data
#     4. Long Term Impact
#         a. Crime
#         b. Real estate
#     5. Conclusions / discussion

# %% [markdown]
# ## 1. Intro
#
# ### a. Workshop Objectives:

# %% [markdown]
# ### Here's a map of the Demolitions in Detroit colored by Neighborhood  - we will be diving deep into this data very soon.  We'll munge data, visualize and plot the data.

# %%
from IPython.display import Image
Image(filename='TotalDemoPerNighDetroit.png')

# %% [markdown]
# ### b. Tutorials

# %% [markdown]
# ###  But first thing first -- let's go through some core functionalities about Python Jupyter notebooks.

# %%
Image(filename='jupyter_menu.jpg')

# %% [markdown]
# ### To simplify things here's a copy of the upper menu you all see in your Jupyter notebooks and it is numbered 1-7.
#
# - 1 simply saves your work similiar to other types of docs
# - 2 is used in order to add a new IN cell
# - If you make a mistake or just don't need a specific cell anymore, press 3 to crop it. Carfeull not clicking it by accident when trying to add a cell..
# - 4 shifts the chosen cell one spot higher in your notebook and 5 does the same but toward down
# - 6 is used to run the chosen cell, this will genenrate the cell's output
# - 7 is used to change a cell's funcilnality, the two main ones we will use today is: code (defeault) and Markdown which is mainly used to write comments and titels.
#
# #### More useful things:
#
# - if the notebook is stuck, or if you want to restart it - go to 'Kernel' and click - 'Restart'
# - if you only want to run parts of the notebook - go to 'Cell' and choose the most suitable options: (Run All, Run All Above and Run All Bellow are some of the popular ones).
# - To save a copy of your work, go to File - Download As : we recommend HTML or IPYNB to restore with viz
# - To run a cell using only the keyboard press shift-return at the same time.

# %% [markdown]
# #### Now, let's practice some of what we've learned:
#
# Please create 3 new cells
#
# 1. In the first cell:
#
# print ("Hello Detroit, I'm *your name* !" )
#
# 2. in the second cell:
# Sum up your birthday digits (month + day + year)
# Hint: write an equation using plus sings and exlcuding the = sign
#
# 3. Define variable of your choice (* = number / equation) and then: print (the variable)

# %% [markdown]
# #### Great!
#
# Now change the order of the cells so that instead of 1,2,3 they are ordered 3,1,2. Got it?

# %% [markdown]
# If you want to expend your Jupyter and Pandas in psrtcular knowldge we recommend strating with :http://pandas.pydata.org/pandas-docs/version/0.15.2/tutorials.html

# %% [markdown]
# ### Coding tools, packages and languages:
# Today we will be using Python and in particular Pandas and Geopandas as toolf of data manipulation, cleaning, merging, visualzation, plotting and many more fanctionalitites that make working with big spreadhsheets easier.

# %% [markdown]
# Let's import the packages we need:

# %%
#import packages

import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3.  Demolitions

# %% [markdown]
# ### Read datasets
# We will be loading CSV files, which are similiar to spreadsheets and, and GeoJson which is a geographical data format mainly used to represen points and polygons.
#
# First let's load the demolitions data which is downloaded from the Detroit open data portal in a CSV format, Pandas will trasnform it into a DataFrame, which is a two-dimensional format ( bascially columns and rows). Values can be numeric, string, boolean etc.

# %%
#load Demolitions data 
demolitions = pd.read_csv('Detroit_Demolitions.csv')

# %% [markdown]
# Demolitions

# %%
#how many demolitions over the years 2014-2018
print ("The total number of demolitions is:",len(demolitions))
# Out:
# The total number of demolitions is: 14524

# %% [markdown]
# ### Data Cleaning

# %%
# remove NaN's  
demolitions = demolitions.dropna()

# %% [markdown]
# ### Demolitions Cost

# %%
print ("The total price of demolitions is $" + str(demolitions['Price'].sum() / 1000000)+"M")
# Out:
# The total price of demolitions is $228.31201243M

# %%
#group by neighborhoods to have the total price for demolitions for each
dem = demolitions.groupby(['Neighborhood']).sum()

# %% [markdown]
# ### dem is a DF with USD spent on demolitions by neighborhood

# %%
#let's see how does it looks like
dem.head(4)
# Out:
#                        Price  Council_District     Latitude     Longitude
# Neighborhood
# Airport Sub       3942161.75               714  9242.481514 -18099.234705
# Aviation Sub        64718.40                28   169.423262   -332.650528
# Bagley             167511.00                20   424.264473   -831.466834
# Barton-McFarland  3174172.63              1340  8133.953885 -15967.729907

# %% [markdown]
# This dataframe summs up all numerical columns (price, council district, Lat, Lon). However, except for price, all columns agragated this way actually have no meaning so they are noise we actually want to remove from the data.
# Let's do that:

# %%
# delete columns 

del dem['Council_District']
del dem['Latitude']
del dem['Longitude']


dem.head()
# Out:
#                        Price
# Neighborhood
# Airport Sub       3942161.75
# Aviation Sub        64718.40
# Bagley             167511.00
# Barton-McFarland  3174172.63
# Belmont            105975.52

# %% [markdown]
# Now that looks better, but let's try to better understand the cost of demolitions by neighborhood. Eyeballing the dataframe makes it a little hard to come up with meaningful conclusions..
# Ploting the data will make it easier to grasp. Let's do it

# %%
# first thing first: in the group.by process the column we grouped on (i.e.  neighborhood) 
#colapses into the DataFrame index.
# to make it easiar to interact with let's create a new column which equals to the index (== Neighborhood)
dem['Neighborhood'] = dem.index

# %%
#let's see how it looks like: 
dem.head()
# Out:
#                        Price      Neighborhood
# Neighborhood
# Airport Sub       3942161.75       Airport Sub
# Aviation Sub        64718.40      Aviation Sub
# Bagley             167511.00            Bagley
# Barton-McFarland  3174172.63  Barton-McFarland
# Belmont            105975.52           Belmont

# %% [markdown]
# Beautiful

# %%
# now let's sort the data so that the lowest priced neighborhood will apear first 
dem = dem.sort_values(by='Price')

# %%
print ("four least demolitions funded neighborhoods in Detroit are:",dem.head(4))
print ("four most demolitions funded neighborhoods in Detroit are:",dem.tail(4))
# Out:
# four least demolitions funded neighborhoods in Detroit are:                        Price         Neighborhood
# Neighborhood
# Greenwich             9310.0            Greenwich
# Green Acres          13726.0          Green Acres
# McNichols Evergreen  13900.0  McNichols Evergreen
# Rivertown            16550.0            Rivertown
# four most demolitions funded neighborhoods in Detroit are:                         Price       Neighborhood
# Neighborhood
# Claytown           6096510.79           Claytown
# Dexter-Linwood     6328961.55     Dexter-Linwood
# Holcomb Community  6897702.58  Holcomb Community
# Warrendale         9494484.32         Warrendale

# %% [markdown]
# So we can see that more than 9 Million USD were spent on demolitions in the neoghborhood of Warrendale, and only 9,000 USD were sepent in Greenwich

# %%
#Let's plot them all together 
plt.figure(figsize=(37,13))
dem['Price'].plot.bar(stacked=False,fontsize=13)

plt.show()

# %% [markdown]
# Pretty cool but, we as we are intrested by those neighborhoods with the most funds allocated to demolitions we can zoom in and only plot less of them

# %%
#let's see how many neghbohoords do we actually have 
len(dem)
# Out:
# 172

# %% [markdown]
# let's try and plot the top 20%

# %%
dem = dem.tail(20)

# %%
plt.figure(figsize=(33,15))
plt.title('Top 20% Detroit neighbohorhoods most demolitions spending',  fontsize=27)
dem['Price'].plot.bar(stacked=False, fontsize=24)

plt.show()

# %% [markdown]
# ### Compare funding from HHF and NON-HHF

# %%
demolitions['Primary_Funding_Source'] =  demolitions['Primary Funding Source']

# %%
# seperate df : nonUHF and UHF funds
nonHHFdem = (demolitions[demolitions['Primary_Funding_Source']== 'Non-HHF'])
HHFdem = (demolitions[demolitions['Primary_Funding_Source']== 'HHF'])                     
print (len(nonHHFdem))
print (len(HHFdem))
print (len(demolitions))
#(comp[comp['BoroughID']== 1])
# Out:
# 3918
# 10606
# 14524

# %%
print (HHFdem.head(2))
print (nonHHFdem.head(2))
# Out:
#             Address  Parcel ID  Contractor Name    Price  \
# 14   211 Trowbridge  01003322.  Able Demolition  15049.0
# 15  16700 Evergreen  22095679.  DMC Consultants   7861.4
#
#    Primary Funding Source Demolition Date Commercial Building  \
# 14                    HHF      09/10/2014                  No
# 15                    HHF      06/03/2014                  No
#
#     Council_District         Neighborhood   Latitude  Longitude  \
# 14                 5    Gateway Community  42.390861 -83.083073
# 15                 1  North Rosedale Park  42.411668 -83.237590
#
#                              Location Primary_Funding_Source
# 14  location\n(42.390861, -83.083073)                    HHF
# 15   location\n(42.411668, -83.23759)                    HHF
#        Address  Parcel ID Contractor Name    Price Primary Funding Source  \
# 0  6754 W Fort  18000464.         Smalley  23800.0                Non-HHF
# 1  5528 Martin  18011033.         Smalley  18500.0                Non-HHF
#
#   Demolition Date Commercial Building  Council_District Neighborhood  \
# 0      07/19/2018                  No                 6       Delray
# 1      07/11/2018                  No                 6     Claytown
#
#     Latitude  Longitude                           Location  \
# 0  42.304381 -83.109600    location\n(42.304381, -83.1096)
# 1  42.338227 -83.132268  location\n(42.338227, -83.132268)
#
#   Primary_Funding_Source
# 0                Non-HHF
# 1                Non-HHF

# %%
# grouop.by contracor name for NHF and nonNHF funded 
nonHHFdem = nonHHFdem.groupby(['Contractor Name']).sum()
HHFdem = HHFdem.groupby(['Contractor Name']).sum()

# %%
# remove columns , only keep price 
del nonHHFdem['Council_District']
del nonHHFdem['Latitude']
del nonHHFdem['Longitude']


del HHFdem['Council_District']
del HHFdem['Latitude']
del HHFdem['Longitude']

# %%
print (nonHHFdem.head(4))
print (HHFdem.head(4))
# Out:
#                             Price
# Contractor Name
# 1 Way Service          3189257.00
# 313 Construction, LLC    38817.77
# ABC Demolition          329395.00
# Able Demolition        9371192.70
#                              Price
# Contractor Name
# 313 Construction, LLC    464818.61
# ABC Demolition          5197899.00
# Able Demolition        13512933.68
# Adamo Group, Inc.      40280635.38

# %%
nonHHFdem['PriceNonHHF'] = nonHHFdem['Price']
HHFdem['PriceHHF'] = HHFdem['Price']

# %%
print (nonHHFdem.head(10))
print (HHFdem.head(4))
# Out:
#                                         Price  PriceNonHHF
# Contractor Name
# 1 Way Service                      3189257.00   3189257.00
# 313 Construction, LLC                38817.77     38817.77
# ABC Demolition                      329395.00    329395.00
# Able Demolition                    9371192.70   9371192.70
# Adamo Group, Inc.                 12295740.33  12295740.33
# BBEK Environmental                   10000.00     10000.00
# Blackstar                            15400.00     15400.00
# Blue Star                          3076100.00   3076100.00
# Brown & Glo Wrecking                212847.00    212847.00
# Brown Environmental Construction   2583315.90   2583315.90
#                              Price     PriceHHF
# Contractor Name
# 313 Construction, LLC    464818.61    464818.61
# ABC Demolition          5197899.00   5197899.00
# Able Demolition        13512933.68  13512933.68
# Adamo Group, Inc.      40280635.38  40280635.38

# %%
#index to column 
nonHHFdem['Contractor_Name'] = nonHHFdem.index
HHFdem['Contractor_Name'] = HHFdem.index

# %%
demHHF_merged = pd.merge(nonHHFdem, HHFdem , on = 'Contractor_Name', how = "inner")

# %%
demHHF_merged.head()
# Out:
#        Price_x  PriceNonHHF        Contractor_Name      Price_y     PriceHHF
# 0     38817.77     38817.77  313 Construction, LLC    464818.61    464818.61
# 1    329395.00    329395.00         ABC Demolition   5197899.00   5197899.00
# 2   9371192.70   9371192.70        Able Demolition  13512933.68  13512933.68
# 3  12295740.33  12295740.33      Adamo Group, Inc.  40280635.38  40280635.38
# 4   3076100.00   3076100.00              Blue Star   3937099.00   3937099.00

# %%
del demHHF_merged['Price_x']
del demHHF_merged['Price_y']

# %%
demHHF_merged.head()
# Out:
#    PriceNonHHF        Contractor_Name     PriceHHF
# 0     38817.77  313 Construction, LLC    464818.61
# 1    329395.00         ABC Demolition   5197899.00
# 2   9371192.70        Able Demolition  13512933.68
# 3  12295740.33      Adamo Group, Inc.  40280635.38
# 4   3076100.00              Blue Star   3937099.00

# %%
demHHF_merged.plot(alpha=0.6,figsize = (7,4))
#demUHF_merged.plot(c='k',marker='.',ax=ax, alpha=0.6)
#plt.show()



plt.show()

# %%
from shapely.geometry import Point

# %%
# Demolitions DF to GeoDF 

from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(demolitions.Longitude, demolitions.Latitude)]
demolitions = demolitions.drop(['Longitude', 'Latitude'], axis=1)
crs = {'init': 'epsg:4326'}

# %%
#create a new DataFrame for the geo points 
gdf = gpd.GeoDataFrame(demolitions, crs=crs, geometry=geometry)

# %%
DetroitNeighborhoods = gpd.read_file('DetroitNeighborhoods.geojson')
DetroitNeighborhoods = DetroitNeighborhoods.to_crs({'init': 'epsg:4326'})

# %%
DetroitNeighborhoods.head()
# Out:
#            acres     shape_area join_count district_nu objectid_1 nhood_num  \
# 0  1086.49884204  31710328.0781          3           4          1        75
# 1  496.783595203  21639806.8475          1           4          2        25
# 2  1159.77563198  31188710.5449          1           4          3        60
# 3  901.711919191  39278414.0858          2           4          4        97
# 4   964.17407249  41999254.6002          1           4          5       123
#
#   objectid     shape_leng          nhood_name           new_nhood neighborho  \
# 0        1  27277.0743136       Gratiot Woods            West End        103
# 1        2    18822.43192       Chandler Park       Chandler Park        105
# 2        3  30500.9332741           Fox Creek           Riverbend        100
# 3        4  25466.5795687  Jefferson Chalmers  Jefferson Chalmers        101
# 4        5  26596.6920683         Morningside         Morningside         97
#
#   target_fid     shape_le_1                                           geometry
# 0          1  31380.7300469  (POLYGON ((-82.9915246858219 42.38438953003659...
# 1          2    18822.43192  (POLYGON ((-82.97584899959158 42.3893319996678...
# 2          3  22537.8470224  (POLYGON ((-82.96784188332737 42.3836942899373...
# 3          4  25466.5795687  (POLYGON ((-82.95140600040769 42.3550279999058...
# 4          5  26596.6920683  (POLYGON ((-82.94664400037011 42.3874689998093...

# %%
DetroitNeighborhoods['Neighborhood'] = DetroitNeighborhoods['nhood_name']

# %%
ax = DetroitNeighborhoods.plot(alpha=0.6,figsize = (15,16))
#f, ax = plt.subplots(1,figsize = (15,16))

plt.show()

# %%
f, ax = plt.subplots(1,figsize = (15,16))
gdf.plot(c='c',marker='.',ax=ax, alpha=0.6)
plt.show()

# %% [markdown]
# ## 4. Short term impact

# %% [markdown]
# ??? 311 improve detroit demolitions related data

# %%
# <your code>

# %% [markdown]
# ## 5. Long term impact

# %% [markdown]
# ### a. Crime
# We want to learn more about how Detroit's neighborhoods were influnced by the demolitions policy over time. As the policy was first intruduced in 2014 and are ongoing until now - 2018, we'd need to evaluate impact by comparing a specific varaible that might have been influnced in the period when the demolitions were conducted.
#
# Let's check out crime levels in Detroit's neighbohoods. We will use data from Detroit's open data portal for 2013 (to reflect crime levels just before the policy was introduced) and 2017 (the most recent full year).
#
# Since the crime incidents open datasets have changes in format over time and since our lab has time, and computation power limitations we have manipulated the 2013 and 2017 datasets ahead of time and combined them into one cleaned CSV file grouoped by neighborhood level.
#
# ## ** If you are intrested to see the data cleaning process you can check out this repo
# https://github.com/avigailvantu/Detroit-prep
#
# The raw data icludes All Crime Incidents for 2013 and 2017 and is available here:
#
# https://data.detroitmi.gov/browse?q=crime&sortBy=relevance

# %%
#Loading Crime Data
DetCrime = pd.read_csv('DetCrime13_17.csv')

#DetCrime13_17.csv

# %%
#let's clean duplicated column to avoid silly plotting
del DetCrime['Unnamed: 0']

# %%
DetCrime.head(4)
# Out:
#          Neighborhood  Incidents17  Incidents13
# 0            West End          352          693
# 1       Chandler Park          346          405
# 2           Riverbend          487          675
# 3  Jefferson Chalmers          468          654

# %%
DetCrime.plot(alpha=0.6,figsize = (13,8))

# %% [markdown]
# Is this plot providing valauable infomration? , if not, can you think of a different way to use this infomration to derieve a better understanding about Detroit's crime level related to the demolitions data?

# %%
# sort 2017 
#dem = dem.sort_values(by='Price')
DetCrime = DetCrime.sort_values(by='Incidents17')

# plot 2017

plt.figure(figsize=(33,15))
plt.title('2017 crime levels in Detroit per Neighborhood',  fontsize=27)
DetCrime['Incidents17'].plot.bar(stacked=False, fontsize=24)
plt.show()

#sort 2013 

plt.figure(figsize=(33,15))
plt.title('2013 crime levels in Detroit per Neighborhood',  fontsize=27)
DetCrime['Incidents13'].plot.bar(stacked=False, fontsize=24)

plt.show()

# %%
#DetCrime

#group by Neighborhood name again, but this time count and not sum 
dem2 = demolitions.groupby(['Neighborhood']).count()

# %%
dem2.head()
# Out:
#                   Address  Parcel ID  Contractor Name  Price  \
# Neighborhood
# Airport Sub           218        218              218    218
# Aviation Sub            4          4                4      4
# Bagley                 10         10               10     10
# Barton-McFarland      192        192              192    192
# Belmont                 8          8                8      8
#
#                   Primary Funding Source  Demolition Date  \
# Neighborhood
# Airport Sub                          218              218
# Aviation Sub                           4                4
# Bagley                                10               10
# Barton-McFarland                     192              192
# Belmont                                8                8
#
#                   Commercial Building  Council_District  Location  \
# Neighborhood
# Airport Sub                       218               218       218
# Aviation Sub                        4                 4         4
# Bagley                             10                10        10
# Barton-McFarland                  192               192       192
# Belmont                             8                 8         8
#
#                   Primary_Funding_Source  geometry
# Neighborhood
# Airport Sub                          218       218
# Aviation Sub                           4         4
# Bagley                                10        10
# Barton-McFarland                     192       192
# Belmont                                8         8

# %% [markdown]
# Basically each one of the columns reflects number of incidents since we applied a "count"

# %%
#let's combine the Demolitions count to the crime data

DetCrime['NumDemolitions'] = dem2['Address']

# %%
DetCrime.head()
# Out:
#         Neighborhood  Incidents17  Incidents13  NumDemolitions
# 149       Belle Isle            6          132             NaN
# 156  Waterworks Park           14           18             NaN
# 89          Douglass           18           10             NaN
# 100    Virginia Park           25           41             NaN
# 56        Arden Park           27           37             NaN

# %%
dem2['NumDemolitions'] = dem2['Address']

# %%
# merge crime and demolitions data 
DetDemCrimeMerge = pd.merge(DetCrime,  dem2 , on = 'Neighborhood', how = "inner")

# %%
DetDemCrimeMerge
# Out:
#               Neighborhood  Incidents17  Incidents13  NumDemolitions_x  \
# 0       West Virginia Park           28           28               NaN
# 1          Oakwood Heights           33           89               NaN
# 2             Carbon Works           41           63               NaN
# 3        Historic Atkinson           41           41               NaN
# 4             Medbury Park           41          111               NaN
# 5              Happy Homes           52           88               NaN
# 6            East Canfield           59           77               NaN
# 7         Seven Mile Lodge           66          106               NaN
# 8              Old Redford           76          130               NaN
# 9              Mexicantown           77          113               NaN
# 10           Herman Kiefer           83          173               NaN
# 11                 Paveway           83           94               NaN
# 12             Minock Park           87          113               NaN
# 13     Southfield Plymouth           90          175               NaN
# 14         Hubbard Richard          109          125               NaN
# 15            North Campau          116          175               NaN
# 16        West Outer Drive          118          200               NaN
# 17          Conant Gardens          122          170               NaN
# 18         Michigan-Martin          123          198               NaN
# 19            Pingree Park          125          238               NaN
# 20    West Side Industrial          127          209               NaN
# 21             Green Acres          128          193               NaN
# 22     Northwest Community          130          184               NaN
# 23      Cadillac Community          131          202               NaN
# 24          Wildemere Park          132          205               NaN
# 25           Westwood Park          134          178               NaN
# 26                 Penrose          135          254               NaN
# 27          Dexter-Fenkell          137          205               NaN
# 28                 Jamison          138          281               NaN
# 29            South of Six          140          195               NaN
# ..                     ...          ...          ...               ...
# 143   Evergreen Lahser 7/8          765          978               NaN
# 144      Holcomb Community          789          935               NaN
# 145                Winship          807          940               NaN
# 146             Greenfield          857         1075               NaN
# 147          Moross-Morang          860         1181               NaN
# 148             Mapleridge          862         1257               NaN
# 149   Fitzgerald/Marygrove          894         1523               NaN
# 150            Airport Sub          903         1351               NaN
# 151         Crary/St Marys          923         1144               NaN
# 152           College Park          934         1029               NaN
# 153                Schulze          992         1337               NaN
# 154            Springwells         1027         1621               NaN
# 155                 Bagley         1030         1669               NaN
# 156                  Nolan         1040         1473               NaN
# 157   Warren Ave Community         1045         1408               NaN
# 158            Morningside         1102         1514               NaN
# 159      Central Southwest         1119         1829               NaN
# 160  Oakman Blvd Community         1120         1546               NaN
# 161                Midwest         1130         1899               NaN
# 162      Outer Drive-Hayes         1147         1700               NaN
# 163      Bethune Community         1166         1731               NaN
# 164             Brightmoor         1182         1747               NaN
# 165         Dexter-Linwood         1187         1737               NaN
# 166               Claytown         1188         2120               NaN
# 167       Barton-McFarland         1194         1775               NaN
# 168    Cornerstone Village         1201         1516               NaN
# 169            Regent Park         1355         1820               NaN
# 170                Midtown         1383         2358               NaN
# 171          Franklin Park         1513         2111               NaN
# 172             Warrendale         2407         3337               NaN
#
#      Address  Parcel ID  Contractor Name  Price  Primary Funding Source  \
# 0          2          2                2      2                       2
# 1          2          2                2      2                       2
# 2         13         13               13     13                      13
# 3          2          2                2      2                       2
# 4          2          2                2      2                       2
# 5          6          6                6      6                       6
# 6         22         22               22     22                      22
# 7          1          1                1      1                       1
# 8          8          8                8      8                       8
# 9          1          1                1      1                       1
# 10        89         89               89     89                      89
# 11         5          5                5      5                       5
# 12         2          2                2      2                       2
# 13         9          9                9      9                       9
# 14         1          1                1      1                       1
# 15        49         49               49     49                      49
# 16         2          2                2      2                       2
# 17        54         54               54     54                      54
# 18        34         34               34     34                      34
# 19        83         83               83     83                      83
# 20         4          4                4      4                       4
# 21         1          1                1      1                       1
# 22        12         12               12     12                      12
# 23        15         15               15     15                      15
# 24       124        124              124    124                     124
# 25       159        159              159    159                     159
# 26        36         36               36     36                      36
# 27        71         71               71     71                      71
# 28       111        111              111    111                     111
# 29        14         14               14     14                      14
# ..       ...        ...              ...    ...                     ...
# 143       91         91               91     91                      91
# 144      485        485              485    485                     485
# 145        9          9                9      9                       9
# 146       45         45               45     45                      45
# 147       44         44               44     44                      44
# 148      279        279              279    279                     279
# 149      242        242              242    242                     242
# 150      218        218              218    218                     218
# 151       31         31               31     31                      31
# 152       87         87               87     87                      87
# 153       13         13               13     13                      13
# 154      198        198              198    198                     198
# 155       10         10               10     10                      10
# 156      120        120              120    120                     120
# 157      185        185              185    185                     185
# 158      315        315              315    315                     315
# 159      160        160              160    160                     160
# 160      238        238              238    238                     238
# 161      240        240              240    240                     240
# 162      395        395              395    395                     395
# 163      185        185              185    185                     185
# 164      437        437              437    437                     437
# 165      194        194              194    194                     194
# 166      415        415              415    415                     415
# 167      192        192              192    192                     192
# 168      108        108              108    108                     108
# 169      344        344              344    344                     344
# 170        2          2                2      2                       2
# 171      174        174              174    174                     174
# 172      653        653              653    653                     653
#
#      Demolition Date  Commercial Building  Council_District  Location  \
# 0                  2                    2                 2         2
# 1                  2                    2                 2         2
# 2                 13                   13                13        13
# 3                  2                    2                 2         2
# 4                  2                    2                 2         2
# 5                  6                    6                 6         6
# 6                 22                   22                22        22
# 7                  1                    1                 1         1
# 8                  8                    8                 8         8
# 9                  1                    1                 1         1
# 10                89                   89                89        89
# 11                 5                    5                 5         5
# 12                 2                    2                 2         2
# 13                 9                    9                 9         9
# 14                 1                    1                 1         1
# 15                49                   49                49        49
# 16                 2                    2                 2         2
# 17                54                   54                54        54
# 18                34                   34                34        34
# 19                83                   83                83        83
# 20                 4                    4                 4         4
# 21                 1                    1                 1         1
# 22                12                   12                12        12
# 23                15                   15                15        15
# 24               124                  124               124       124
# 25               159                  159               159       159
# 26                36                   36                36        36
# 27                71                   71                71        71
# 28               111                  111               111       111
# 29                14                   14                14        14
# ..               ...                  ...               ...       ...
# 143               91                   91                91        91
# 144              485                  485               485       485
# 145                9                    9                 9         9
# 146               45                   45                45        45
# 147               44                   44                44        44
# 148              279                  279               279       279
# 149              242                  242               242       242
# 150              218                  218               218       218
# 151               31                   31                31        31
# 152               87                   87                87        87
# 153               13                   13                13        13
# 154              198                  198               198       198
# 155               10                   10                10        10
# 156              120                  120               120       120
# 157              185                  185               185       185
# 158              315                  315               315       315
# 159              160                  160               160       160
# 160              238                  238               238       238
# 161              240                  240               240       240
# 162              395                  395               395       395
# 163              185                  185               185       185
# 164              437                  437               437       437
# 165              194                  194               194       194
# 166              415                  415               415       415
# 167              192                  192               192       192
# 168              108                  108               108       108
# 169              344                  344               344       344
# 170                2                    2                 2         2
# 171              174                  174               174       174
# 172              653                  653               653       653
#
#      Primary_Funding_Source  geometry  NumDemolitions_y
# 0                         2         2                 2
# 1                         2         2                 2
# 2                        13        13                13
# 3                         2         2                 2
# 4                         2         2                 2
# 5                         6         6                 6
# 6                        22        22                22
# 7                         1         1                 1
# 8                         8         8                 8
# 9                         1         1                 1
# 10                       89        89                89
# 11                        5         5                 5
# 12                        2         2                 2
# 13                        9         9                 9
# 14                        1         1                 1
# 15                       49        49                49
# 16                        2         2                 2
# 17                       54        54                54
# 18                       34        34                34
# 19                       83        83                83
# 20                        4         4                 4
# 21                        1         1                 1
# 22                       12        12                12
# 23                       15        15                15
# 24                      124       124               124
# 25                      159       159               159
# 26                       36        36                36
# 27                       71        71                71
# 28                      111       111               111
# 29                       14        14                14
# ..                      ...       ...               ...
# 143                      91        91                91
# 144                     485       485               485
# 145                       9         9                 9
# 146                      45        45                45
# 147                      44        44                44
# 148                     279       279               279
# 149                     242       242               242
# 150                     218       218               218
# 151                      31        31                31
# 152                      87        87                87
# 153                      13        13                13
# 154                     198       198               198
# 155                      10        10                10
# 156                     120       120               120
# 157                     185       185               185
# 158                     315       315               315
# 159                     160       160               160
# 160                     238       238               238
# 161                     240       240               240
# 162                     395       395               395
# 163                     185       185               185
# 164                     437       437               437
# 165                     194       194               194
# 166                     415       415               415
# 167                     192       192               192
# 168                     108       108               108
# 169                     344       344               344
# 170                       2         2                 2
# 171                     174       174               174
# 172                     653       653               653
#
# [173 rows x 16 columns]

# %%
a = {'Neighborhood': DetDemCrimeMerge['Neighborhood'] , 'Incidents17': DetDemCrimeMerge['Incidents17'], 'Incidents13': DetDemCrimeMerge['Incidents13'],'NumDemolitions': DetDemCrimeMerge['NumDemolitions_y']}
DetCrimeFinal = pd.DataFrame(data=a)

# %%
# DetCrimeFinal is the merged data for crime incicdents in 2013 / 2017 and the number of demolitions
DetCrimeFinal.tail(20)
# Out:
#               Neighborhood  Incidents17  Incidents13  NumDemolitions
# 153                Schulze          992         1337              13
# 154            Springwells         1027         1621             198
# 155                 Bagley         1030         1669              10
# 156                  Nolan         1040         1473             120
# 157   Warren Ave Community         1045         1408             185
# 158            Morningside         1102         1514             315
# 159      Central Southwest         1119         1829             160
# 160  Oakman Blvd Community         1120         1546             238
# 161                Midwest         1130         1899             240
# 162      Outer Drive-Hayes         1147         1700             395
# 163      Bethune Community         1166         1731             185
# 164             Brightmoor         1182         1747             437
# 165         Dexter-Linwood         1187         1737             194
# 166               Claytown         1188         2120             415
# 167       Barton-McFarland         1194         1775             192
# 168    Cornerstone Village         1201         1516             108
# 169            Regent Park         1355         1820             344
# 170                Midtown         1383         2358               2
# 171          Franklin Park         1513         2111             174
# 172             Warrendale         2407         3337             653

# %%
# calcaulte crime precentage change between 2013 and 2017 

# (incindets 2017) minus (incidents 2013) divided by (incidents 2013)  multiplaid by 100
DetCrimeFinal['P_Change'] = ((DetCrimeFinal['Incidents17'] - DetCrimeFinal['Incidents13']) / (DetCrimeFinal['Incidents13'] )* 100)

# %%
DetCrimeFinal.tail()
# Out:
#             Neighborhood  Incidents17  Incidents13  NumDemolitions   P_Change
# 168  Cornerstone Village         1201         1516             108 -20.778364
# 169          Regent Park         1355         1820             344 -25.549451
# 170              Midtown         1383         2358               2 -41.348601
# 171        Franklin Park         1513         2111             174 -28.327807
# 172           Warrendale         2407         3337             653 -27.869344

# %%
DetCrimeFinal.plot(by= 'P_Change')

# %%
plt.figure(figsize=(33,15))
plt.title('2013-2017  crime P_Change',  fontsize=27)
DetCrimeFinal['P_Change'].plot.bar(stacked=False, fontsize=24)

# %%
#sort
DetCrimeFinal = DetCrimeFinal.sort_values(by='NumDemolitions')

# %%
DetCrimeFinal.tail(3)
# Out:
#           Neighborhood  Incidents17  Incidents13  NumDemolitions   P_Change
# 164         Brightmoor         1182         1747             437 -32.341156
# 144  Holcomb Community          789          935             485 -15.614973
# 172         Warrendale         2407         3337             653 -27.869344

# %%
# some descriptives about the % change
print ("Describe", DetCrimeFinal.P_Change.describe())
# Out:
# Describe count    173.000000
# mean     -27.438609
# std       19.421719
# min      -63.063063
# 25%      -35.662432
# 50%      -30.434783
# 75%      -22.489960
# max       98.907104
# Name: P_Change, dtype: float64

# %%
DetCrimeFinal[DetCrimeFinal["P_Change"] >  -27.438609]
# Out:
#                Neighborhood  Incidents17  Incidents13  NumDemolitions  \
# 14          Hubbard Richard          109          125               1
# 51       Milwaukee Junction          198          132               1
# 31      McNichols Evergreen          143          162               1
# 107          Lafayette Park          365          451               1
# 0        West Virginia Park           28           28               2
# 12              Minock Park           87          113               2
# 3         Historic Atkinson           41           41               2
# 46              Forest Park          193          249               3
# 70             Aviation Sub          254          348               4
# 113          Mohican Regent          401          454               5
# 75           Eastern Market          269          370               5
# 50             Castle Rouge          196          237               5
# 11                  Paveway           83           94               5
# 41            Hubbard Farms          172          185               6
# 67                Grandmont          248          291               7
# 109                 Belmont          372          348               8
# 145                 Winship          807          940               9
# 45             Eliza Howell          183          158               9
# 116     North Rosedale Park          426          543              10
# 106               Oak Grove          364          183              12
# 105               Oak Grove          364          234              12
# 115         Greenfield Park          415          246              13
# 153                 Schulze          992         1337              13
# 124         Harmony Village          486          608              20
# 40                Ravendale          171          175              20
# 6             East Canfield           59           77              22
# 60             Miller Grove          224          258              23
# 57               Piety Hill          221          275              25
# 88     LaSalle College Park          322          429              28
# 91              Five Points          327          391              29
# ..                      ...          ...          ...             ...
# 42             Joy-Schaefer          173          200              39
# 68     Pride Area Community          252          274              40
# 92     Grand River-St Marys          328          414              40
# 147           Moross-Morang          860         1181              44
# 146              Greenfield          857         1075              45
# 71                 Fiskhorn          257          339              47
# 134        Plymouth-Hubbell          625          769              56
# 87           Grixdale Farms          320          341              60
# 78              NW Goldberg          281          352              64
# 74             Garden Homes          266          358              68
# 142             Von Steuben          743          853              74
# 131                 Nortown          574          647              79
# 39   Chandler Park-Chalmers          169          160              82
# 152            College Park          934         1029              87
# 143    Evergreen Lahser 7/8          765          978              91
# 94          Buffalo Charles          331          437              95
# 114               Fox Creek          409          530              97
# 96            Chandler Park          346          405              98
# 135             O'Hair Park          645          807             103
# 168     Cornerstone Village         1201         1516             108
# 58             Plymouth-I96          221          301             153
# 25            Westwood Park          134          178             159
# 136            Conner Creek          662          831             161
# 133              Islandview          623          824             168
# 157    Warren Ave Community         1045         1408             185
# 61            Gratiot Woods          229          308             212
# 141                 Pulaski          726          927             293
# 158             Morningside         1102         1514             315
# 169             Regent Park         1355         1820             344
# 144       Holcomb Community          789          935             485
#
#       P_Change
# 14  -12.800000
# 51   50.000000
# 31  -11.728395
# 107 -19.068736
# 0     0.000000
# 12  -23.008850
# 3     0.000000
# 46  -22.489960
# 70  -27.011494
# 113 -11.674009
# 75  -27.297297
# 50  -17.299578
# 11  -11.702128
# 41   -7.027027
# 67  -14.776632
# 109   6.896552
# 145 -14.148936
# 45   15.822785
# 116 -21.546961
# 106  98.907104
# 105  55.555556
# 115  68.699187
# 153 -25.804039
# 124 -20.065789
# 40   -2.285714
# 6   -23.376623
# 60  -13.178295
# 57  -19.636364
# 88  -24.941725
# 91  -16.368286
# ..         ...
# 42  -13.500000
# 68   -8.029197
# 92  -20.772947
# 147 -27.180356
# 146 -20.279070
# 71  -24.188791
# 134 -18.725618
# 87   -6.158358
# 78  -20.170455
# 74  -25.698324
# 142 -12.895662
# 131 -11.282844
# 39    5.625000
# 152  -9.232264
# 143 -21.779141
# 94  -24.256293
# 114 -22.830189
# 96  -14.567901
# 135 -20.074349
# 168 -20.778364
# 58  -26.578073
# 25  -24.719101
# 136 -20.336943
# 133 -24.393204
# 157 -25.781250
# 61  -25.649351
# 141 -21.682848
# 158 -27.212682
# 169 -25.549451
# 144 -15.614973
#
# [63 rows x 5 columns]

# %% [markdown]
# ### b. Real Estate

# %% [markdown]
# ## 6. Conclusions / Discussion

# %% [markdown]
# ## 7. Survey

# %% [markdown]
# #### Thank you for participating in our workshop! It would be very helpful for us if you could take a few minutes to fill out a survey to provide feedback about your experience.

# %% [markdown]
# Q1. Did you had any previous data analytics / visualizations experience?

# %% [markdown]
# < your answer>

# %% [markdown]
# Q2. Are you from Detroit or very familiar with the city?

# %% [markdown]
# < your answer>

# %% [markdown]
# Q3. What is the most interesting thing you learned throughout the workshop ?

# %% [markdown]
# < your answer>

# %% [markdown]
# Q4. Why were you drawn to this Open Demolitions workshop in the first place?

# %% [markdown]
# < your answer>

# %% [markdown]
# Q5. Did the workshop fulfil your what you hoped to achieve?

# %% [markdown]
# < your answer>

# %% [markdown]
# Q6. If you could add one more section to the workshop, what would that be?

# %% [markdown]
# < your answer>

# %% [markdown]
# ### Thank You!
